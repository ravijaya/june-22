# %%
import pandas as pd

df = pd.read_csv('employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null object
# Start Date           1000 non-null object
# Last Login Time      1000 non-null object
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    933 non-null object
# Team                 957 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
pd.to_datetime(df['Last Login Time'])  # there is not date, its pick today date by default
# Out:
# 0     2018-06-21 12:42:00
# 1     2018-06-21 06:53:00
# 2     2018-06-21 11:17:00
# 3     2018-06-21 13:00:00
# 4     2018-06-21 16:47:00
# 5     2018-06-21 01:35:00
# 6     2018-06-21 16:20:00
# 7     2018-06-21 10:43:00
# 8     2018-06-21 06:29:00
# 9     2018-06-21 06:51:00
# 10    2018-06-21 09:01:00
# 11    2018-06-21 15:19:00
# 12    2018-06-21 01:08:00
# 13    2018-06-21 23:40:00
# 14    2018-06-21 07:13:00
# 15    2018-06-21 06:09:00
# 16    2018-06-21 05:56:00
# 17    2018-06-21 19:45:00
# 18    2018-06-21 10:27:00
# 19    2018-06-21 03:48:00
# 20    2018-06-21 19:18:00
# 21    2018-06-21 02:12:00
# 22    2018-06-21 01:58:00
# 23    2018-06-21 16:19:00
# 24    2018-06-21 22:08:00
# 25    2018-06-21 01:12:00
# 26    2018-06-21 07:45:00
# 27    2018-06-21 18:58:00
# 28    2018-06-21 18:30:00
# 29    2018-06-21 22:06:00
#               ...
# 970   2018-06-21 20:54:00
# 971   2018-06-21 02:01:00
# 972   2018-06-21 14:49:00
# 973   2018-06-21 23:08:00
# 974   2018-06-21 18:31:00
# ...

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               1000 non-null bool
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(2), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 48.9+ KB

# %%
import pandas as pd

df = pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
# First Name           933 non-null object
# Gender               855 non-null category
# Start Date           1000 non-null datetime64[ns]
# Last Login Time      1000 non-null datetime64[ns]
# Salary               1000 non-null int64
# Bonus %              1000 non-null float64
# Senior Management    1000 non-null bool
# Team                 957 non-null object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# # filter a dataframe based on a condition

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12      True
# 13      True
# 14     False
# 15     False
# 16      True
# 17      True
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 970    False
# 971     True
# 972    False
# 973     True
# 974     True
# 975    False
# 976    False
# 977    False
# 978     True
# 979     True
# 980    False
# 981     True
# 982    False
# 983     True
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992     True
# 993    False
# 994     True
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 12     Brandon   Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 13        Gary   Male 2008-01-27 2018-06-21 23:40:00  109831    5.831
# 16      Jeremy   Male 2010-09-21 2018-06-21 05:56:00   90370    7.369
# 17       Shawn   Male 1986-12-07 2018-06-21 19:45:00  111737    6.414
# 21     Matthew   Male 1995-09-05 2018-06-21 02:12:00  100612   13.645
# 23         NaN   Male 2012-06-14 2018-06-21 16:19:00  125792    5.042
# 24        John   Male 1992-07-01 2018-06-21 22:08:00   97950   13.873
# ...

# %%
df[df['Bonus %'] <= 6]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 13        Gary    Male 2008-01-27 2018-06-21 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2018-06-21 06:09:00   59414    1.256
# 19       Donna  Female 2010-07-22 2018-06-21 03:48:00   81014    1.894
# 20        Lois     NaN 1995-04-22 2018-06-21 19:18:00   64714    4.934
# 23         NaN    Male 2012-06-14 2018-06-21 16:19:00  125792    5.042
# 27       Scott     NaN 1991-07-11 2018-06-21 18:58:00  122367    5.218
# 38   Stephanie  Female 1986-09-13 2018-06-21 01:52:00   36844    5.574
# 40     Michael    Male 2008-10-10 2018-06-21 11:25:00   99283    2.665
# 43     Marilyn  Female 1980-12-07 2018-06-21 03:16:00   73524    5.207
# 49       Chris     NaN 1980-01-24 2018-06-21 12:13:00  113590    3.055
# ...

# %%
mask = df['Team'] == 'Finance'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2018-06-21 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2018-06-21 22:47:00  114796    6.796
# 53        Alan     NaN 2014-03-03 2018-06-21 13:28:00   40341   17.578
# 56        Carl    Male 2006-05-03 2018-06-21 17:55:00  130276   16.084
# 67      Rachel  Female 1999-08-16 2018-06-21 06:53:00   51178    9.735
# 68        Jose    Male 2004-10-30 2018-06-21 13:39:00   84834   14.330
# 69       Irene     NaN 2015-07-14 2018-06-21 16:31:00  100863    4.382
# 83       Shawn    Male 2005-09-23 2018-06-21 02:55:00  148115    6.539
# 84       Doris  Female 2004-08-20 2018-06-21 05:51:00   83072    7.511
# ...

# %%
df[df['Senior Management']]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 14    Kimberly  Female 1999-01-14 2018-06-21 07:13:00   41426   14.543
# ...

# %%
df[df['Team'] != 'Marketing']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# ...

# %%
df[df['Salary'] >= 100000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 13        Gary    Male 2008-01-27 2018-06-21 23:40:00  109831    5.831
# 17       Shawn    Male 1986-12-07 2018-06-21 19:45:00  111737    6.414
# 18       Diana  Female 1981-10-23 2018-06-21 10:27:00  132940   19.082
# 21     Matthew    Male 1995-09-05 2018-06-21 02:12:00  100612   13.645
# 23         NaN    Male 2012-06-14 2018-06-21 16:19:00  125792    5.042
# ...

# %%
# Out:
#    First Name  Gender Start Date     Last Login Time    Salary  Bonus %  \
# 0     Marilyn  Female 1985-11-21 2018-06-21 13:35:00   86676.0    8.999
# 1         NaN     NaN 1988-04-15                 NaT   91462.0   12.182
# 2         NaN     NaN 1988-06-26                 NaT  121160.0      NaN
# 3         NaN     NaN 1994-09-23                 NaT  145988.0      NaN
# 4         NaN     NaN 1994-10-30                 NaT  147183.0      NaN
# 5         NaN     NaN 1995-04-07                 NaT       NaN      NaN
# 6         NaN     NaN 1995-04-24                 NaT       NaN      NaN
# 7         NaN     NaN 1995-10-23                 NaT       NaN      NaN
# 8         NaN     NaN 1996-03-31                 NaT       NaN      NaN
# 9         NaN     NaN 1996-04-18                 NaT       NaN      NaN
# 10        NaN     NaN 1997-09-03                 NaT       NaN      NaN
# 11        NaN     NaN 1999-04-13                 NaT       NaN      NaN
# ...

# %%
df['Start Date'] <= "1982-01-17"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28      True
# 29     False
#        ...
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994    False
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Start Date, Length: 1000, dtype: bool

# %%
df[df['Start Date'] <= "1982-01-17"]
# Out:
#      First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10       Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 12      Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 18        Diana  Female 1981-10-23 2018-06-21 10:27:00  132940   19.082
# 28        Terry    Male 1981-11-27 2018-06-21 18:30:00  124008   13.464
# 37        Linda  Female 1981-10-19 2018-06-21 20:49:00   57427    9.557
# 43      Marilyn  Female 1980-12-07 2018-06-21 03:16:00   73524    5.207
# 45        Roger    Male 1980-04-17 2018-06-21 11:32:00   88010   13.886
# 49        Chris     NaN 1980-01-24 2018-06-21 12:13:00  113590    3.055
# 82       Steven    Male 1980-03-30 2018-06-21 21:20:00   35095    8.379
# 94        Harry    Male 1981-08-26 2018-06-21 15:16:00  130620    7.030
# 140     Shirley  Female 1981-02-28 2018-06-21 13:23:00  113850    1.854
# 154     Rebecca  Female 1980-11-15 2018-06-21 04:13:00   85730    5.359
# ...

# %%
len(df[df['Start Date'] <= "1982-01-17"])
# Out:
# 51

# %%
df[df['Start Date'] <= "1982-01-17"].count()
# Out:
# First Name           46
# Gender               42
# Start Date           51
# Last Login Time      51
# Salary               51
# Bonus %              51
# Senior Management    51
# Team                 48
# dtype: int64

# %% [markdown]
# # filtering using more then one condition

# %%
import pandas as pd

df = pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask1 = df['Gender'] == 'Male'
mask2 = df['Team'] == 'Marketing'
df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2018-06-21 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2018-06-21 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2018-06-21 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2018-06-21 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2018-06-21 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2018-06-21 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2018-06-21 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2018-06-21 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2018-06-21 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2018-06-21 09:45:00   55281    4.935
# ...

# %%
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 3        Jerry   Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 21     Matthew   Male 1995-09-05 2018-06-21 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2018-06-21 07:45:00   37598    7.757
# 46       Bruce   Male 2009-11-28 2018-06-21 22:47:00  114796    6.796
# 56        Carl   Male 2006-05-03 2018-06-21 17:55:00  130276   16.084
# 68        Jose   Male 2004-10-30 2018-06-21 13:39:00   84834   14.330
# 74      Thomas   Male 1995-06-04 2018-06-21 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2018-06-21 20:13:00  107391    1.260
# 83       Shawn   Male 2005-09-23 2018-06-21 02:55:00  148115    6.539
# 101      Aaron   Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2018-06-21 07:01:00   80740   19.305
# ...

# %%
df[df['Senior Management'] | (df['Start Date'] <= '1982-01-17')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 14    Kimberly  Female 1999-01-14 2018-06-21 07:13:00   41426   14.543
# ...

# %%
mask1 = df['Gender'] == 'Male'
mask2 = df['Team'] == 'Marketing'
mask3 = df['Team'] == 'Finance'

df[mask1 & (mask2 | mask3)]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 3        Jerry   Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 21     Matthew   Male 1995-09-05 2018-06-21 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2018-06-21 07:45:00   37598    7.757
# 46       Bruce   Male 2009-11-28 2018-06-21 22:47:00  114796    6.796
# 56        Carl   Male 2006-05-03 2018-06-21 17:55:00  130276   16.084
# 68        Jose   Male 2004-10-30 2018-06-21 13:39:00   84834   14.330
# 74      Thomas   Male 1995-06-04 2018-06-21 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2018-06-21 20:13:00  107391    1.260
# 83       Shawn   Male 2005-09-23 2018-06-21 02:55:00  148115    6.539
# 101      Aaron   Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2018-06-21 07:01:00   80740   19.305
# ...

# %%
mask1 = df['First Name'] == 'Robert'
mask2 = df['Team'] == 'Client Services'
mask3 = df['Start Date'] > '2016-06-01'
df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2018-06-21 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2018-06-21 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2018-06-21 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2018-06-21 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# # isin() methods

# %%
import pandas as pd

df = pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask = df['Team'].isin(['Legal', 'Sales', 'Product'])
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5         Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 6           Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 11         Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 13          Gary    Male 2008-01-27 2018-06-21 23:40:00  109831    5.831
# 15       Lillian  Female 2016-06-05 2018-06-21 06:09:00   59414    1.256
# 17         Shawn    Male 1986-12-07 2018-06-21 19:45:00  111737    6.414
# 19         Donna  Female 2010-07-22 2018-06-21 03:48:00   81014    1.894
# 20          Lois     NaN 1995-04-22 2018-06-21 19:18:00   64714    4.934
# 27         Scott     NaN 1991-07-11 2018-06-21 18:58:00  122367    5.218
# 29      Benjamin    Male 2005-01-26 2018-06-21 22:06:00   79529    7.008
# 31         Joyce     NaN 2005-02-20 2018-06-21 14:40:00   88657   12.752
# 35       Theresa  Female 2006-10-10 2018-06-21 01:12:00   85182   16.675
# ...

# %% [markdown]
# # isnull and .notnull methods

# %%
df[df['Team'].isnull()]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2018-06-21 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2018-06-21 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2018-06-21 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2018-06-21 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2018-06-21 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2018-06-21 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2018-06-21 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2018-06-21 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2018-06-21 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2018-06-21 06:06:00   66067   10.957
# ...

# %%
df[df['Team'].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2018-06-21 01:08:00  112807   17.492
# 13        Gary    Male 2008-01-27 2018-06-21 23:40:00  109831    5.831
# ...

# %%
df[df['Gender'].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2018-06-21 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2018-06-21 15:19:00  102508   12.637
# ...

# %%
df['Gender'].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %% [markdown]
# # .between

# %%
df[df['Salary'].between(60000, 90000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2018-06-21 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 19       Donna  Female 2010-07-22 2018-06-21 03:48:00   81014    1.894
# 20        Lois     NaN 1995-04-22 2018-06-21 19:18:00   64714    4.934
# 29    Benjamin    Male 2005-01-26 2018-06-21 22:06:00   79529    7.008
# 31       Joyce     NaN 2005-02-20 2018-06-21 14:40:00   88657   12.752
# 35     Theresa  Female 2006-10-10 2018-06-21 01:12:00   85182   16.675
# 41   Christine     NaN 2015-06-28 2018-06-21 01:08:00   66582   11.308
# 43     Marilyn  Female 1980-12-07 2018-06-21 03:16:00   73524    5.207
# 45       Roger    Male 1980-04-17 2018-06-21 11:32:00   88010   13.886
# 47       Kathy  Female 2005-06-22 2018-06-21 04:51:00   66820    9.000
# ...

# %%
df[df['Start Date'].between('2016-01-01', '2018-01-06')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2018-06-21 06:09:00   59414    1.256
# 39         NaN    Male 2016-01-29 2018-06-21 02:33:00  122173    7.797
# 89      Janice  Female 2016-03-12 2018-06-21 00:40:00   51082   11.955
# 98        Tina  Female 2016-06-16 2018-06-21 19:47:00  100705   16.961
# 121   Kathleen     NaN 2016-05-09 2018-06-21 08:55:00  119735   18.740
# 143     Teresa     NaN 2016-01-28 2018-06-21 10:55:00  140013    8.689
# 239    Lillian     NaN 2016-05-12 2018-06-21 15:43:00   64164   17.612
# 426       Todd    Male 2016-03-16 2018-06-21 14:45:00  134408    3.560
# 444        NaN    Male 2016-05-24 2018-06-21 21:17:00   76409    7.008
# 451      Terry     NaN 2016-07-15 2018-06-21 00:29:00  140002   19.490
# 496     Johnny    Male 2016-02-26 2018-06-21 19:39:00   76394    5.437
# 684      Alice  Female 2016-01-21 2018-06-21 17:07:00  117787   10.485
# ...

# %%
df[df['Last Login Time'].between('8:30am', '12:00pm')]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2          Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 7            NaN  Female 2015-07-20 2018-06-21 10:43:00   45906   11.598
# 10        Louise  Female 1980-08-12 2018-06-21 09:01:00   63241   15.132
# 18         Diana  Female 1981-10-23 2018-06-21 10:27:00  132940   19.082
# 33          Jean  Female 1993-12-18 2018-06-21 09:07:00  119082   16.180
# 40       Michael    Male 2008-10-10 2018-06-21 11:25:00   99283    2.665
# 45         Roger    Male 1980-04-17 2018-06-21 11:32:00   88010   13.886
# 54          Sara  Female 2007-08-15 2018-06-21 09:23:00   83677    8.999
# 59         Irene  Female 1997-05-07 2018-06-21 09:32:00   66851   11.279
# 72         Bobby    Male 2007-05-07 2018-06-21 10:01:00   54043    3.833
# 81   Christopher    Male 2008-03-30 2018-06-21 10:52:00   47369   14.822
# 85        Jeremy    Male 2008-02-01 2018-06-21 08:50:00  100238    3.887
# ...

# %% [markdown]
# # .duplicated()

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2018-06-21 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2018-06-21 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2018-06-21 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2018-06-21 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2018-06-21 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.sort_values('First Name', inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2018-06-21 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2018-06-21 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2018-06-21 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2018-06-21 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df['First Name'][:30]
# Out:
# 101     Aaron
# 327     Aaron
# 440     Aaron
# 937     Aaron
# 137      Adam
# 141      Adam
# 302      Adam
# 538      Adam
# 300      Alan
# 53       Alan
# 610      Alan
# 372    Albert
# 458    Albert
# 477    Albert
# 680    Albert
# 999    Albert
# 959    Albert
# 988     Alice
# 970     Alice
# 765     Alice
# 425     Alice
# 905     Alice
# 684     Alice
# 935     Alice
# 693     Alice
# 639    Amanda
# 642    Amanda
# 578    Amanda
# 553    Amanda
# 542    Amanda
# Name: First Name, dtype: object

# %%
df[df['First Name'].duplicated(keep=False)]  # get list of duplicate records
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2018-06-21 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2018-06-21 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2018-06-21 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2018-06-21 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2018-06-21 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2018-06-21 11:59:00   71276    5.027
# 538       Adam    Male 2010-10-08 2018-06-21 21:53:00   45181    3.491
# 300       Alan    Male 1988-06-26 2018-06-21 03:54:00  111786    3.592
# 53        Alan     NaN 2014-03-03 2018-06-21 13:28:00   40341   17.578
# 610       Alan    Male 2012-02-17 2018-06-21 00:26:00   41453   10.084
# 372     Albert    Male 1997-02-01 2018-06-21 16:20:00   67827   19.717
# ...

# %%
df[~df['First Name'].duplicated(keep=False)]  # not
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-06-21 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-06-21 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-06-21 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2018-06-21 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2018-06-21 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2018-06-21 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2018-06-21 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %%
df.drop_duplicates(subset='First Name')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2018-06-21 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2018-06-21 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2018-06-21 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2018-06-21 09:34:00   47638   11.209
# 639     Amanda     NaN 1991-08-11 2018-06-21 14:15:00   46665   19.391
# 879        Amy  Female 2009-05-20 2018-06-21 06:26:00   75415   19.132
# 430     Andrea  Female 2010-10-01 2018-06-21 11:54:00   79123   19.422
# 564     Andrew    Male 1985-03-29 2018-06-21 18:57:00   43414    7.563
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 509        Ann  Female 1984-11-04 2018-06-21 12:17:00   90719    6.220
# 645       Anna     NaN 1985-03-13 2018-06-21 09:19:00   45418   10.162
# ...

# %%
df.drop_duplicates(subset='Gender')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2018-06-21 10:20:00   61602   11.849
# 937      Aaron     NaN 1986-01-22 2018-06-21 19:39:00   63126   18.424
# 988      Alice  Female 2004-10-05 2018-06-21 09:34:00   47638   11.209
#
#      Senior Management             Team
# 101               True        Marketing
# 937              False  Client Services
# 988              False  Human Resources

# %%
df.drop_duplicates(subset='First Name', keep=False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2018-06-21 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2018-06-21 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2018-06-21 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2018-06-21 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2018-06-21 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2018-06-21 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2018-06-21 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2018-06-21 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2018-06-21 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# # .unique()  and .nunique() methods

# %%
df['Gender'].unique()
# Out:
# [Male, NaN, Female]
# Categories (2, object): [Male, Female]

# %%
df['Team'].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
df['Team'].nunique()
# Out:
# 10

# %%
df['Team'].nunique(dropna=False)
# Out:
# 11
